# %%
import matplotlib.pyplot as plt
all_colors = ['#2E94B9', "#fa625f", '#62C8A5', '#f29c2b']
x = [1,10,100,200,400,600,800,1000]
ClusterNN_AUC =  [0.98789541, 0.98208163, 0.96753967, 0.95718087, 0.93884512,
       0.92017866, 0.90028622, 0.87873732]
IFOREST_AUC = [0.9874107142857143, 0.9784438775510204, 0.9584934948979591, 0.9438584821428573,
               0.9182639349489796, 0.8947168154761904, 0.8715869100765308, 0.8487100892857145]
XGBOD_AUC =   [0.9985841836734695, 0.9930031887755102, 0.9687598214285714, 0.9418404017857144,
               0.8744178411989796, 0.8102776573129252, 0.7593526945153062, 0.7196182971938776]
CatB_AUC = [0.9294770408163265, 0.9257206632653062, 0.9140702806122449, 0.9020053571428572,
            0.8805443558673469, 0.8611993835034013, 0.8425479113520408, 0.8249923852040817]

plt.plot(x, ClusterNN_AUC,'o-', color = all_colors[0], label = 'ClusterNN',linewidth = 1.5)
plt.plot(x, IFOREST_AUC,'P-', color = all_colors[1], label = 'IForest',linewidth = 1.5)
plt.plot(x, XGBOD_AUC,'X-', color = all_colors[2], label = 'XGBOD',linewidth = 1.5)
plt.plot(x, CatB_AUC,'^-', color = all_colors[3], label = 'CatB',linewidth = 1.5 )
plt.legend(frameon=False, ncol=2)
plt.xlabel(r'$\beta$ value')
plt.ylabel('AUC value')
plt.savefig(f'../figures/quantitative_evaluation.png',dpi=600)
plt.savefig(f'../figures/quantitative_evaluation.pdf')
